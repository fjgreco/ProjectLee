# %% [markdown]
# ## NotebookExploration4DataScience_v1
#
# Contact: Frank Greco  fjgreco@uchicago.edu for help

# %% [markdown]
# ### Guidance for working with this notebook:
#
# #### This notebook is being provided as a place to experiment and learn more about Python and data science.
#
# #### Best practice: make a copy of this notebook using the File/Make a Copy menu option. Keep the original as a master and work off the copy, which you may rename and modify as desired.
#
# #### Links to <font color=green>references</font> for the various Python packages and methods used in the notebook are included throughout.  The links  found at the end of this notebook are to some multi-topic public data repositories that contain data you may find interesting to download and explore.
#
# ####   A  '!' at the beginning of a line  e.g., !pip and !rm found below, directs the line to your local (laptop) command environment (not to Python).
#
# #### Un-comment and run any of the following pip install commands as needed.  Be sure to re-comment afterwards, as the installations needonly be run once.  (Note the use of '!')

# %%
#!pip install pandas

# %%
#!pip install numpy

# %%
#!pip install matplotlib

# %%
#!pip install seaborn

# %%
#!pip install sklearn

# %%
#!pip install wget

# %% [markdown]
# ### pandas
#
# <font color=green>Reference</font> https://pandas.pydata.org/

# %%
import pandas as pd

# %% [markdown]
# ### numpy
#
# https://numpy.org/

# %%
import numpy as np

# %% [markdown]
# ### matplotlib
#
# <font color=green>Reference</font> https://matplotlib.org/

# %%
# import for visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### seaborn
# <font color=green>Reference</font> https://seaborn.pydata.org/

# %%
import seaborn as sns

# %% [markdown]
# ### sklearn
#
# <font color=green>Reference</font> https://scikit-learn.org/stable/

# %%
# imports for math and stats
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import MinMaxScaler
from sklearn import datasets, linear_model

from sklearn.datasets import make_classification
from sklearn.ensemble import ExtraTreesClassifier

from sklearn import ensemble
from sklearn import datasets
from sklearn.utils import shuffle
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### wget
#
# <font color=green>Reference</font> https://www.gnu.org/software/wget/

# %%
import wget

# %% [markdown]
# ## Get worldwide Covid19 data
#
# Source: https://github.com/owid/covid-19-data/tree/master/public/data

# %%
covid19_url="https://covid.ourworldindata.org/data/owid-covid-data.csv"

# %%
body_covid19="owid-covid-data.csv"

# %% [markdown]
# #### Remove older  coved19  data file from the local directory:

# %%
# !rm $body_covid19
# Out:
# rm: owid-covid-data.csv: No such file or directory

# %% [markdown]
# #### Get the current  covid19 data file:

# %%
wget.download(covid19_url,body_covid19)
# Out:
# 'owid-covid-data.csv'

# %% [markdown]
# #### Read the csv file into a pandas data frame:

# %%
df_covid19_ = pd.read_csv(body_covid19)

# %% [markdown]
# #### View the first 5 rows.  To see more (or less)  rows use df_covid19.head( 'number of rows'):

# %%
df_covid19_.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0        1803.987              NaN                597.029
# 1        1803.987              NaN                597.029
# 2        1803.987              NaN                597.029
# 3        1803.987              NaN                597.029
# 4        1803.987              NaN                597.029
#
#    diabetes_prevalence  female_smokers  male_smokers  handwashing_facilities  \
# 0                 9.59             NaN           NaN                  37.746
# 1                 9.59             NaN           NaN                  37.746
# 2                 9.59             NaN           NaN                  37.746
# 3                 9.59             NaN           NaN                  37.746
# 4                 9.59             NaN           NaN                  37.746
#
#    hospital_beds_per_thousand  life_expectancy  human_development_index
# 0                         0.5            64.83                    0.511
# 1                         0.5            64.83                    0.511
# 2                         0.5            64.83                    0.511
# 3                         0.5            64.83                    0.511
# 4                         0.5            64.83                    0.511
#
# [5 rows x 59 columns]

# %% [markdown]
# #### When displaying a data frame, pandas by default limits the number of rows shown.  To set the number  rows df_covid19_ run the set the max_rows value and run the follow cell.
#
# Note: df_covid19_.shape[0]+1 yields the number of rows in the df_covid19_  dataframe. Use a similar approach for any other dataframe.
#
# <font color=red>Warning: Having set the display limit to a large number, as will happen when using the total number of rows in a large dataframe as a max_rows value, can result in overloading your laptop when viewing large dataframes:</font>

# %% [raw]
# max_rows=100    # set to what ever value >0 you want
#
# pd.set_option('display.max_rows', max_rows)

# %% [markdown]
# #### The following cell is an example of how to select rows based on a pattern or search criteria.

# %% [raw]
# df_covid19=df_covid19_[df_covid19_['date']=='2020-07-16']

# %% [markdown]
# #### Obtain the most recent entry for a each country:

# %%
df_covid19=df_covid19_.groupby(['location']).max()

# %%
df_covid19.reset_index(inplace=True)

# %% [markdown]
# ####  <font color= green>Matplotlib tutorials:</font>
#
# https://www.tutorialspoint.com/matplotlib/matplotlib_bar_plot.htm
#
# https://pythonbasics.org/matplotlib-bar-chart

# %% [markdown]
# #### <font color=red>Quick, dirty and hard to read</font>

# %%
df_covid19.plot.bar(x='location', y='total_cases')
# Out:
# <AxesSubplot:xlabel='location'>

# %% [markdown]
# #### <font color=orange>Using matplotlib affords control the framesize and over how the ticks are displayed. Still, the presentation is not ideal: </font>

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt

data = df_covid19['total_cases']
labels = df_covid19['location']
plt.figure(figsize=(20,20))
plt.xticks(range(len(data)), labels, rotation=45)
plt.xlabel('Country')
plt.ylabel('Total Cases')
plt.title('Total Cases by Country')
plt.bar(range(len(data)), data) 
plt.show()

# %% [markdown]
# #### <font color=teal>Changing the orientation from a vertical to a horizontal bar chart helps. But, the ordering of the countries appears random and the country names don't match 1 for 1 with the total cases.</font>

# %%
data = df_covid19['total_cases']
labels = df_covid19['location']
plt.figure(figsize=(30,20))
spaced_y = [3*i for i in range(len(data))]
plt.yticks(spaced_y, labels)
plt.ylabel('Country')
plt.xlabel('Total Cases')
plt.title('Total Cases by Country')
plt.barh(range(len(data)), data) 
plt.show()

# %% [markdown]
# ### <font color=Blue>We sort the dataframe by 'total_cases' and display a meaningful subset of results:</font>
#
# <font color=green>Reference:</font> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html

# %%
df_sorted_result = df_covid19.sort_values(by='total_cases',ascending=False)

# %%
df_sorted_result.head()
# Out:
#           location  iso_code      continent        date  total_cases  \
# 224          World  OWID_WRL            NaN  2021-05-26  168412812.0
# 11            Asia  OWID_ASI            NaN  2021-05-26   50065902.0
# 67          Europe  OWID_EUR            NaN  2021-05-26   46630003.0
# 150  North America  OWID_NAM            NaN  2021-05-26   38761444.0
# 216  United States       USA  North America  2021-05-26   33190470.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 224   905992.0          826374.286     3498443.0     17906.0
# 11    525129.0          497521.143      662491.0      6206.0
# 67    346447.0          287095.143     1068396.0      7554.0
# 150   327335.0          278986.429      873366.0      7003.0
# 216   300310.0          251056.857      591950.0      4475.0
#
#      new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 224            14436.286  ...       15469.207             10.0
# 11              5699.571  ...             NaN              NaN
# 67              5608.286  ...             NaN              NaN
# 150             4964.286  ...             NaN              NaN
# 216             3432.571  ...       54225.446              1.2
#
#      cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 224                233.070                 8.51           6.434        34.635
# 11                     NaN                  NaN             NaN           NaN
# 67                     NaN                  NaN             NaN           NaN
# 150                    NaN                  NaN             NaN           NaN
# 216                151.089                10.79          19.100        24.600
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 224                   60.13                       2.705            72.58
# 11                      NaN                         NaN              NaN
# 67                      NaN                         NaN              NaN
# 150                     NaN                         NaN              NaN
# 216                     NaN                       2.770            78.86
#
#      human_development_index
# 224                    0.737
# 11                       NaN
# 67                       NaN
# 150                      NaN
# 216                    0.926
#
# [5 rows x 58 columns]

# %%
data = df_sorted_result.head(20)['total_cases']
labels = df_sorted_result.head(20)['location']
plt.figure(figsize=(30,20))
plt.yticks(range(len(data)), labels)
plt.ylabel('Country')
plt.xlabel('Total Cases')
plt.title('Total Cases by Country')
plt.barh(range(len(data)), data) 
plt.show()

# %% [markdown]
# #### Obtain the most recent entry for a specific country:

# %%
df_covid19[df_covid19['location']=='United States']
# Out:
#           location iso_code      continent        date  total_cases  \
# 216  United States      USA  North America  2021-05-26   33190470.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 216   300310.0          251056.857      591950.0      4475.0
#
#      new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 216             3432.571  ...       54225.446              1.2
#
#      cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 216                151.089                10.79            19.1          24.6
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 216                     NaN                        2.77            78.86
#
#      human_development_index
# 216                    0.926
#
# [1 rows x 58 columns]

# %% [markdown]
# #### A sanity check on the sort

# %%
df_sorted_result[df_sorted_result['location']=='United States']
# Out:
#           location iso_code      continent        date  total_cases  \
# 216  United States      USA  North America  2021-05-26   33190470.0
#
#      new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 216   300310.0          251056.857      591950.0      4475.0
#
#      new_deaths_smoothed  ...  gdp_per_capita  extreme_poverty  \
# 216             3432.571  ...       54225.446              1.2
#
#      cardiovasc_death_rate  diabetes_prevalence  female_smokers  male_smokers  \
# 216                151.089                10.79            19.1          24.6
#
#      handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 216                     NaN                        2.77            78.86
#
#      human_development_index
# 216                    0.926
#
# [1 rows x 58 columns]

# %% [markdown]
# ### Look for correlations in the data
#
# <font color=green>Reference:</font> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html

# %%
df_covid19.corr()
# Out:
#                                        total_cases  new_cases  \
# total_cases                               1.000000   0.949759
# new_cases                                 0.949759   1.000000
# new_cases_smoothed                        0.950264   0.996541
# total_deaths                              0.989956   0.913684
# new_deaths                                0.929270   0.923010
# new_deaths_smoothed                       0.975180   0.972010
# total_cases_per_million                   0.058320   0.090578
# new_cases_per_million                    -0.038511  -0.029373
# new_cases_smoothed_per_million           -0.019138   0.002923
# total_deaths_per_million                  0.094835   0.129767
# new_deaths_per_million                   -0.049280  -0.042190
# new_deaths_smoothed_per_million          -0.014277   0.008428
# reproduction_rate                         0.228182   0.283877
# icu_patients                              0.992855   0.975214
# icu_patients_per_million                  0.108386   0.157621
# hosp_patients                             0.959223   0.959042
# hosp_patients_per_million                -0.052488  -0.030932
# weekly_icu_admissions                     0.907443   0.841974
# weekly_icu_admissions_per_million         0.129929   0.009045
# weekly_hosp_admissions                    0.910969   0.892766
# weekly_hosp_admissions_per_million       -0.026499  -0.031984
# new_tests                                 0.695338   0.694342
# total_tests                               0.878523   0.874014
# total_tests_per_thousand                 -0.009250  -0.009253
# new_tests_per_thousand                   -0.020591  -0.016798
# new_tests_smoothed                        0.847974   0.887263
# new_tests_smoothed_per_thousand          -0.031082  -0.022032
# positive_rate                             0.001407   0.009501
# tests_per_case                           -0.079000  -0.082570
# total_vaccinations                        0.933819   0.903134
# people_vaccinated                         0.995107   0.958410
# people_fully_vaccinated                   0.981373   0.930404
# new_vaccinations                          0.873003   0.845015
# new_vaccinations_smoothed                 0.847760   0.833329
# total_vaccinations_per_hundred            0.066701   0.099610
# people_vaccinated_per_hundred             0.043764   0.078302
# people_fully_vaccinated_per_hundred       0.026235   0.048312
# new_vaccinations_smoothed_per_million    -0.007802  -0.004062
# stringency_index                          0.045880   0.070625
# population                                0.904160   0.871923
# population_density                       -0.020194  -0.024880
# median_age                                0.046076   0.087911
# aged_65_older                             0.041595   0.087708
# aged_70_older                             0.037391   0.084085
# gdp_per_capita                            0.022273   0.051652
# extreme_poverty                          -0.046387  -0.066100
# cardiovasc_death_rate                    -0.050553  -0.084737
# diabetes_prevalence                       0.021978   0.025168
# female_smokers                           -0.002708   0.031263
# male_smokers                             -0.013359  -0.036827
# handwashing_facilities                    0.044009   0.059533
# hospital_beds_per_thousand               -0.008955  -0.009405
# life_expectancy                           0.029689   0.063757
# human_development_index                   0.049512   0.088289
#
#                                        new_cases_smoothed  total_deaths  \
# total_cases                                      0.950264      0.989956
# new_cases                                        0.996541      0.913684
# new_cases_smoothed                               1.000000      0.909449
# total_deaths                                     0.909449      1.000000
# new_deaths                                       0.910659      0.935991
# new_deaths_smoothed                              0.966850      0.968564
# total_cases_per_million                          0.068872      0.062256
# new_cases_per_million                           -0.038734     -0.038729
# new_cases_smoothed_per_million                  -0.007355     -0.020191
# total_deaths_per_million                         0.102315      0.124554
# new_deaths_per_million                          -0.055710     -0.038858
# new_deaths_smoothed_per_million                 -0.009965     -0.004901
# reproduction_rate                                0.263967      0.225454
# icu_patients                                     0.988189      0.990201
# icu_patients_per_million                         0.118297      0.109033
# hosp_patients                                    0.974894      0.983286
# hosp_patients_per_million                       -0.033517     -0.006203
# weekly_icu_admissions                            0.896569      0.905850
# weekly_icu_admissions_per_million                0.094326      0.113939
# weekly_hosp_admissions                           0.913736      0.918737
# weekly_hosp_admissions_per_million              -0.031593     -0.014939
# new_tests                                        0.685903      0.653303
# total_tests                                      0.862969      0.762823
# total_tests_per_thousand                        -0.009048     -0.024370
# new_tests_per_thousand                          -0.017276     -0.025282
# new_tests_smoothed                               0.889616      0.716379
# new_tests_smoothed_per_thousand                 -0.022414     -0.041794
# positive_rate                                   -0.002828      0.077166
# tests_per_case                                  -0.071597     -0.090526
# total_vaccinations                               0.910679      0.901243
# people_vaccinated                                0.959565      0.978608
# people_fully_vaccinated                          0.927059      0.974712
# new_vaccinations                                 0.853872      0.841522
# new_vaccinations_smoothed                        0.843977      0.806213
# total_vaccinations_per_hundred                   0.083209      0.068931
# people_vaccinated_per_hundred                    0.058862      0.050307
# people_fully_vaccinated_per_hundred              0.035743      0.030401
# new_vaccinations_smoothed_per_million           -0.007915     -0.006983
# stringency_index                                 0.074097      0.025106
# population                                       0.889601      0.860471
# population_density                              -0.021005     -0.022608
# median_age                                       0.065386      0.046914
# aged_65_older                                    0.061219      0.042673
# aged_70_older                                    0.056259      0.039204
# gdp_per_capita                                   0.034681      0.016671
# extreme_poverty                                 -0.053046     -0.052132
# cardiovasc_death_rate                           -0.065207     -0.051444
# diabetes_prevalence                              0.031731      0.030771
# female_smokers                                   0.006279      0.000177
# male_smokers                                    -0.034722     -0.013109
# handwashing_facilities                           0.052749      0.049299
# hospital_beds_per_thousand                      -0.020080     -0.006650
# life_expectancy                                  0.043178      0.032830
# human_development_index                          0.066038      0.051179
#
#                                        new_deaths  new_deaths_smoothed  \
# total_cases                              0.929270             0.975180
# new_cases                                0.923010             0.972010
# new_cases_smoothed                       0.910659             0.966850
# total_deaths                             0.935991             0.968564
# new_deaths                               1.000000             0.971693
# new_deaths_smoothed                      0.971693             1.000000
# total_cases_per_million                  0.104798             0.090713
# new_cases_per_million                   -0.036408            -0.040666
# new_cases_smoothed_per_million          -0.009871            -0.010156
# total_deaths_per_million                 0.226532             0.167353
# new_deaths_per_million                   0.126436            -0.014636
# new_deaths_smoothed_per_million          0.098536             0.031347
# reproduction_rate                        0.281693             0.269204
# icu_patients                             0.947253             0.972055
# icu_patients_per_million                 0.135983             0.137160
# hosp_patients                            0.979189             0.989935
# hosp_patients_per_million                0.030531             0.028798
# weekly_icu_admissions                    0.809006             0.873232
# weekly_icu_admissions_per_million        0.000903             0.061835
# weekly_hosp_admissions                   0.864050             0.893838
# weekly_hosp_admissions_per_million      -0.042746            -0.035904
# new_tests                                0.480828             0.687662
# total_tests                              0.595020             0.784436
# total_tests_per_thousand                -0.080117            -0.037914
# new_tests_per_thousand                  -0.041422            -0.023615
# new_tests_smoothed                       0.575549             0.791605
# new_tests_smoothed_per_thousand         -0.072618            -0.044560
# positive_rate                            0.217237             0.092575
# tests_per_case                          -0.112160            -0.097942
# total_vaccinations                       0.850344             0.898499
# people_vaccinated                        0.920157             0.969555
# people_fully_vaccinated                  0.910618             0.952142
# new_vaccinations                         0.809560             0.849073
# new_vaccinations_smoothed                0.772719             0.817226
# total_vaccinations_per_hundred           0.087741             0.086135
# people_vaccinated_per_hundred            0.072786             0.067672
# people_fully_vaccinated_per_hundred      0.033106             0.036729
# new_vaccinations_smoothed_per_million   -0.011870            -0.009706
# stringency_index                         0.112937             0.075959
# population                               0.799722             0.861715
# population_density                      -0.038809            -0.027625
# median_age                               0.081471             0.078452
# aged_65_older                            0.079818             0.074388
# aged_70_older                            0.078254             0.071416
# gdp_per_capita                           0.021918             0.030467
# extreme_poverty                         -0.105563            -0.073397
# cardiovasc_death_rate                   -0.124210            -0.084549
# diabetes_prevalence                      0.021494             0.019108
# female_smokers                           0.024507             0.017574
# male_smokers                            -0.054689            -0.040453
# handwashing_facilities                   0.085838             0.063108
# hospital_beds_per_thousand              -0.014565            -0.010148
# life_expectancy                          0.085535             0.057209
# human_development_index                  0.103738             0.080038
#
#                                        total_cases_per_million  \
# total_cases                                           0.058320
# new_cases                                             0.090578
# new_cases_smoothed                                    0.068872
# total_deaths                                          0.062256
# new_deaths                                            0.104798
# new_deaths_smoothed                                   0.090713
# total_cases_per_million                               1.000000
# new_cases_per_million                                 0.476703
# new_cases_smoothed_per_million                        0.757200
# total_deaths_per_million                              0.794970
# new_deaths_per_million                                0.416632
# new_deaths_smoothed_per_million                       0.716200
# reproduction_rate                                     0.297009
# icu_patients                                          0.111978
# icu_patients_per_million                              0.668711
# hosp_patients                                         0.142432
# hosp_patients_per_million                             0.352048
# weekly_icu_admissions                                 0.338501
# weekly_icu_admissions_per_million                     0.665510
# weekly_hosp_admissions                                0.142682
# weekly_hosp_admissions_per_million                    0.197953
# new_tests                                             0.176737
# total_tests                                           0.099452
# total_tests_per_thousand                              0.427929
# new_tests_per_thousand                                0.213786
# new_tests_smoothed                                    0.130487
# new_tests_smoothed_per_thousand                       0.302420
# positive_rate                                         0.078898
# tests_per_case                                       -0.214046
# total_vaccinations                                   -0.007162
# people_vaccinated                                     0.037296
# people_fully_vaccinated                               0.035683
# new_vaccinations                                     -0.057961
# new_vaccinations_smoothed                            -0.038469
# total_vaccinations_per_hundred                        0.635486
# people_vaccinated_per_hundred                         0.639203
# people_fully_vaccinated_per_hundred                   0.580886
# new_vaccinations_smoothed_per_million                 0.238259
# stringency_index                                      0.125533
# population                                           -0.052248
# population_density                                    0.047581
# median_age                                            0.613780
# aged_65_older                                         0.577779
# aged_70_older                                         0.574633
# gdp_per_capita                                        0.477968
# extreme_poverty                                      -0.512453
# cardiovasc_death_rate                                -0.288394
# diabetes_prevalence                                   0.023831
# female_smokers                                        0.642137
# male_smokers                                          0.114688
# handwashing_facilities                                0.552091
# hospital_beds_per_thousand                            0.337135
# life_expectancy                                       0.582255
# human_development_index                               0.622484
#
#                                        new_cases_per_million  \
# total_cases                                        -0.038511
# new_cases                                          -0.029373
# new_cases_smoothed                                 -0.038734
# total_deaths                                       -0.038729
# new_deaths                                         -0.036408
# new_deaths_smoothed                                -0.040666
# total_cases_per_million                             0.476703
# new_cases_per_million                               1.000000
# new_cases_smoothed_per_million                      0.853955
# total_deaths_per_million                            0.263202
# new_deaths_per_million                              0.296720
# new_deaths_smoothed_per_million                     0.319302
# reproduction_rate                                  -0.000184
# icu_patients                                       -0.145685
# icu_patients_per_million                            0.313901
# hosp_patients                                      -0.089813
# hosp_patients_per_million                           0.175179
# weekly_icu_admissions                               0.260343
# weekly_icu_admissions_per_million                   0.106179
# weekly_hosp_admissions                             -0.084666
# weekly_hosp_admissions_per_million                 -0.021919
# new_tests                                           0.078786
# total_tests                                        -0.020318
# total_tests_per_thousand                            0.362838
# new_tests_per_thousand                              0.176033
# new_tests_smoothed                                  0.026896
# new_tests_smoothed_per_thousand                     0.242170
# positive_rate                                       0.002844
# tests_per_case                                     -0.160354
# total_vaccinations                                 -0.050510
# people_vaccinated                                  -0.043064
# people_fully_vaccinated                            -0.050422
# new_vaccinations                                   -0.075092
# new_vaccinations_smoothed                          -0.057444
# total_vaccinations_per_hundred                      0.479740
# people_vaccinated_per_hundred                       0.457760
# people_fully_vaccinated_per_hundred                 0.497510
# new_vaccinations_smoothed_per_million               0.223166
# stringency_index                                    0.075984
# population                                         -0.059923
# population_density                                  0.021656
# median_age                                          0.256501
# aged_65_older                                       0.202117
# aged_70_older                                       0.208476
# gdp_per_capita                                      0.214752
# extreme_poverty                                    -0.211238
# cardiovasc_death_rate                              -0.161418
# diabetes_prevalence                                 0.048448
# female_smokers                                      0.201462
# male_smokers                                        0.057312
# handwashing_facilities                              0.425393
# hospital_beds_per_thousand                          0.130420
# life_expectancy                                     0.238990
# human_development_index                             0.275690
#
#                                        new_cases_smoothed_per_million  \
# total_cases                                                 -0.019138
# new_cases                                                    0.002923
# new_cases_smoothed                                          -0.007355
# total_deaths                                                -0.020191
# new_deaths                                                  -0.009871
# new_deaths_smoothed                                         -0.010156
# total_cases_per_million                                      0.757200
# new_cases_per_million                                        0.853955
# new_cases_smoothed_per_million                               1.000000
# total_deaths_per_million                                     0.504902
# new_deaths_per_million                                       0.331587
# new_deaths_smoothed_per_million                              0.516542
# reproduction_rate                                            0.164340
# icu_patients                                                -0.109105
# icu_patients_per_million                                     0.417051
# hosp_patients                                               -0.019799
# hosp_patients_per_million                                    0.339965
# weekly_icu_admissions                                        0.128934
# weekly_icu_admissions_per_million                            0.355408
# weekly_hosp_admissions                                      -0.100344
# weekly_hosp_admissions_per_million                          -0.035280
# new_tests                                                    0.134178
# total_tests                                                  0.038173
# total_tests_per_thousand                                     0.403008
# new_tests_per_thousand                                       0.209836
# new_tests_smoothed                                           0.089003
# new_tests_smoothed_per_thousand                              0.308062
# positive_rate                                                0.024346
# tests_per_case                                              -0.172758
# total_vaccinations                                          -0.049455
# people_vaccinated                                           -0.027474
# people_fully_vaccinated                                     -0.037503
# new_vaccinations                                            -0.095704
# new_vaccinations_smoothed                                   -0.066781
# total_vaccinations_per_hundred                               0.644585
# people_vaccinated_per_hundred                                0.640555
# people_fully_vaccinated_per_hundred                          0.621278
# new_vaccinations_smoothed_per_million                        0.266829
# stringency_index                                             0.127301
# population                                                  -0.072796
# population_density                                           0.065183
# median_age                                                   0.456608
# aged_65_older                                                0.398282
# aged_70_older                                                0.401558
# gdp_per_capita                                               0.357084
# extreme_poverty                                             -0.381124
# cardiovasc_death_rate                                       -0.252554
# diabetes_prevalence                                          0.050207
# female_smokers                                               0.401437
# male_smokers                                                 0.132142
# handwashing_facilities                                       0.419818
# hospital_beds_per_thousand                                   0.264700
# life_expectancy                                              0.433121
# human_development_index                                      0.480186
#
#                                        total_deaths_per_million  ...  \
# total_cases                                            0.094835  ...
# new_cases                                              0.129767  ...
# new_cases_smoothed                                     0.102315  ...
# total_deaths                                           0.124554  ...
# new_deaths                                             0.226532  ...
# new_deaths_smoothed                                    0.167353  ...
# total_cases_per_million                                0.794970  ...
# new_cases_per_million                                  0.263202  ...
# new_cases_smoothed_per_million                         0.504902  ...
# total_deaths_per_million                               1.000000  ...
# new_deaths_per_million                                 0.503963  ...
# new_deaths_smoothed_per_million                        0.810384  ...
# reproduction_rate                                      0.296012  ...
# icu_patients                                           0.218901  ...
# icu_patients_per_million                               0.855873  ...
# hosp_patients                                          0.281523  ...
# hosp_patients_per_million                              0.835384  ...
# weekly_icu_admissions                                  0.538552  ...
# weekly_icu_admissions_per_million                      0.648262  ...
# weekly_hosp_admissions                                 0.325277  ...
# weekly_hosp_admissions_per_million                     0.393249  ...
# new_tests                                              0.192978  ...
# total_tests                                            0.115829  ...
# total_tests_per_thousand                               0.172393  ...
# new_tests_per_thousand                                 0.144767  ...
# new_tests_smoothed                                     0.158899  ...
# new_tests_smoothed_per_thousand                        0.145089  ...
# positive_rate                                          0.314693  ...
# tests_per_case                                        -0.211655  ...
# total_vaccinations                                     0.016317  ...
# people_vaccinated                                      0.071665  ...
# people_fully_vaccinated                                0.074494  ...
# new_vaccinations                                      -0.025479  ...
# new_vaccinations_smoothed                             -0.018640  ...
# total_vaccinations_per_hundred                         0.408416  ...
# people_vaccinated_per_hundred                          0.435865  ...
# people_fully_vaccinated_per_hundred                    0.338801  ...
# new_vaccinations_smoothed_per_million                  0.125361  ...
# stringency_index                                       0.125254  ...
# population                                            -0.036931  ...
# population_density                                    -0.026692  ...
# median_age                                             0.591256  ...
# aged_65_older                                          0.622689  ...
# aged_70_older                                          0.619052  ...
# gdp_per_capita                                         0.273453  ...
# extreme_poverty                                       -0.466485  ...
# cardiovasc_death_rate                                 -0.194774  ...
# diabetes_prevalence                                   -0.008664  ...
# female_smokers                                         0.679024  ...
# male_smokers                                           0.077422  ...
# handwashing_facilities                                 0.471101  ...
# hospital_beds_per_thousand                             0.335899  ...
# life_expectancy                                        0.504459  ...
# human_development_index                                0.540299  ...
#
#                                        gdp_per_capita  extreme_poverty  \
# total_cases                                  0.022273        -0.046387
# new_cases                                    0.051652        -0.066100
# new_cases_smoothed                           0.034681        -0.053046
# total_deaths                                 0.016671        -0.052132
# new_deaths                                   0.021918        -0.105563
# new_deaths_smoothed                          0.030467        -0.073397
# total_cases_per_million                      0.477968        -0.512453
# new_cases_per_million                        0.214752        -0.211238
# new_cases_smoothed_per_million               0.357084        -0.381124
# total_deaths_per_million                     0.273453        -0.466485
# new_deaths_per_million                       0.136456        -0.262702
# new_deaths_smoothed_per_million              0.272832        -0.440383
# reproduction_rate                            0.375300        -0.404352
# icu_patients                                 0.122047         0.083423
# icu_patients_per_million                    -0.207323         0.188314
# hosp_patients                                0.047337         0.453423
# hosp_patients_per_million                   -0.568277         0.457112
# weekly_icu_admissions                       -0.126153         0.348504
# weekly_icu_admissions_per_million           -0.323808         0.091576
# weekly_hosp_admissions                       0.136722         0.426412
# weekly_hosp_admissions_per_million          -0.415661         0.920524
# new_tests                                    0.203360        -0.101253
# total_tests                                  0.153408        -0.089535
# total_tests_per_thousand                     0.493612        -0.269127
# new_tests_per_thousand                       0.221001        -0.123586
# new_tests_smoothed                           0.166148        -0.081536
# new_tests_smoothed_per_thousand              0.325060        -0.220354
# positive_rate                               -0.214742         0.132881
# tests_per_case                               0.120237        -0.103994
# total_vaccinations                           0.005736        -0.045304
# people_vaccinated                            0.018024        -0.036069
# people_fully_vaccinated                      0.018326        -0.032846
# new_vaccinations                            -0.033235        -0.020535
# new_vaccinations_smoothed                   -0.009799        -0.048357
# total_vaccinations_per_hundred               0.598368        -0.424538
# people_vaccinated_per_hundred                0.579986        -0.449324
# people_fully_vaccinated_per_hundred          0.507190        -0.379161
# new_vaccinations_smoothed_per_million        0.215007        -0.236507
# stringency_index                            -0.125316        -0.266294
# population                                  -0.026141        -0.026372
# population_density                           0.409268        -0.033003
# median_age                                   0.642065        -0.697352
# aged_65_older                                0.491054        -0.573979
# aged_70_older                                0.475995        -0.557852
# gdp_per_capita                               1.000000        -0.502369
# extreme_poverty                             -0.502369         1.000000
# cardiovasc_death_rate                       -0.469170         0.189828
# diabetes_prevalence                          0.141106        -0.378715
# female_smokers                               0.331069        -0.411064
# male_smokers                                -0.093540        -0.192317
# handwashing_facilities                       0.653821        -0.751926
# hospital_beds_per_thousand                   0.291599        -0.443507
# life_expectancy                              0.680478        -0.747518
# human_development_index                      0.754559        -0.777328
#
#                                        cardiovasc_death_rate  \
# total_cases                                        -0.050553
# new_cases                                          -0.084737
# new_cases_smoothed                                 -0.065207
# total_deaths                                       -0.051444
# new_deaths                                         -0.124210
# new_deaths_smoothed                                -0.084549
# total_cases_per_million                            -0.288394
# new_cases_per_million                              -0.161418
# new_cases_smoothed_per_million                     -0.252554
# total_deaths_per_million                           -0.194774
# new_deaths_per_million                             -0.206135
# new_deaths_smoothed_per_million                    -0.262031
# reproduction_rate                                  -0.265647
# icu_patients                                       -0.088757
# icu_patients_per_million                            0.282080
# hosp_patients                                      -0.117248
# hosp_patients_per_million                           0.734869
# weekly_icu_admissions                              -0.321455
# weekly_icu_admissions_per_million                   0.181718
# weekly_hosp_admissions                              0.044532
# weekly_hosp_admissions_per_million                  0.587539
# new_tests                                          -0.128126
# total_tests                                        -0.056553
# total_tests_per_thousand                           -0.187746
# new_tests_per_thousand                             -0.115846
# new_tests_smoothed                                 -0.099415
# new_tests_smoothed_per_thousand                    -0.151432
# positive_rate                                       0.108858
# tests_per_case                                     -0.065425
# total_vaccinations                                 -0.037866
# people_vaccinated                                  -0.049615
# people_fully_vaccinated                            -0.047046
# new_vaccinations                                   -0.012786
# new_vaccinations_smoothed                          -0.026034
# total_vaccinations_per_hundred                     -0.370884
# people_vaccinated_per_hundred                      -0.405119
# people_fully_vaccinated_per_hundred                -0.293761
# new_vaccinations_smoothed_per_million              -0.159338
# stringency_index                                    0.000155
# population                                         -0.019657
# population_density                                 -0.176431
# median_age                                         -0.337437
# aged_65_older                                      -0.336975
# aged_70_older                                      -0.351339
# gdp_per_capita                                     -0.469170
# extreme_poverty                                     0.189828
# cardiovasc_death_rate                               1.000000
# diabetes_prevalence                                 0.122696
# female_smokers                                     -0.171532
# male_smokers                                        0.414670
# handwashing_facilities                             -0.005299
# hospital_beds_per_thousand                          0.041359
# life_expectancy                                    -0.466364
# human_development_index                            -0.420290
#
#                                        diabetes_prevalence  female_smokers  \
# total_cases                                       0.021978       -0.002708
# new_cases                                         0.025168        0.031263
# new_cases_smoothed                                0.031731        0.006279
# total_deaths                                      0.030771        0.000177
# new_deaths                                        0.021494        0.024507
# new_deaths_smoothed                               0.019108        0.017574
# total_cases_per_million                           0.023831        0.642137
# new_cases_per_million                             0.048448        0.201462
# new_cases_smoothed_per_million                    0.050207        0.401437
# total_deaths_per_million                         -0.008664        0.679024
# new_deaths_per_million                           -0.016482        0.269455
# new_deaths_smoothed_per_million                  -0.071497        0.574755
# reproduction_rate                                 0.020097        0.283284
# icu_patients                                      0.429161        0.010399
# icu_patients_per_million                          0.067977        0.636868
# hosp_patients                                     0.404490       -0.008516
# hosp_patients_per_million                         0.020090        0.573732
# weekly_icu_admissions                             0.184684        0.486396
# weekly_icu_admissions_per_million                 0.302976        0.221379
# weekly_hosp_admissions                            0.478299       -0.057113
# weekly_hosp_admissions_per_million                0.280071        0.228276
# new_tests                                         0.034222        0.218692
# total_tests                                       0.120407        0.078403
# total_tests_per_thousand                          0.127850        0.338622
# new_tests_per_thousand                            0.006285        0.278565
# new_tests_smoothed                                0.070424        0.132028
# new_tests_smoothed_per_thousand                   0.063667        0.299297
# positive_rate                                    -0.017974        0.007830
# tests_per_case                                    0.016280       -0.050746
# total_vaccinations                                0.015246       -0.037340
# people_vaccinated                                 0.009865       -0.013915
# people_fully_vaccinated                           0.017352       -0.002876
# new_vaccinations                                  0.022752       -0.072391
# new_vaccinations_smoothed                         0.020421       -0.056462
# total_vaccinations_per_hundred                    0.196851        0.455107
# people_vaccinated_per_hundred                     0.203273        0.546086
# people_fully_vaccinated_per_hundred               0.162000        0.371118
# new_vaccinations_smoothed_per_million             0.148551        0.424731
# stringency_index                                  0.059773       -0.060129
# population                                        0.002508       -0.062912
# population_density                                0.014709       -0.045456
# median_age                                        0.156344        0.667988
# aged_65_older                                    -0.051305        0.766228
# aged_70_older                                    -0.079943        0.768377
# gdp_per_capita                                    0.141106        0.331069
# extreme_poverty                                  -0.378715       -0.411064
# cardiovasc_death_rate                             0.122696       -0.171532
# diabetes_prevalence                               1.000000        0.036659
# female_smokers                                    0.036659        1.000000
# male_smokers                                      0.177364        0.201066
# handwashing_facilities                            0.467357        0.297126
# hospital_beds_per_thousand                       -0.056418        0.495414
# life_expectancy                                   0.203408        0.459004
# human_development_index                           0.212740        0.582359
#
#                                        male_smokers  handwashing_facilities  \
# total_cases                               -0.013359                0.044009
# new_cases                                 -0.036827                0.059533
# new_cases_smoothed                        -0.034722                0.052749
# total_deaths                              -0.013109                0.049299
# new_deaths                                -0.054689                0.085838
# new_deaths_smoothed                       -0.040453                0.063108
# total_cases_per_million                    0.114688                0.552091
# new_cases_per_million                      0.057312                0.425393
# new_cases_smoothed_per_million             0.132142                0.419818
# total_deaths_per_million                   0.077422                0.471101
# new_deaths_per_million                    -0.022664                0.211858
# new_deaths_smoothed_per_million            0.038606                0.376117
# reproduction_rate                          0.030321                0.313653
# icu_patients                              -0.117000                     NaN
# icu_patients_per_million                   0.355915                     NaN
# hosp_patients                             -0.107546                     NaN
# hosp_patients_per_million                  0.551072                     NaN
# weekly_icu_admissions                     -0.012139                     NaN
# weekly_icu_admissions_per_million          0.169712                     NaN
# weekly_hosp_admissions                    -0.150905                     NaN
# weekly_hosp_admissions_per_million         0.239831                     NaN
# new_tests                                 -0.055584                0.038384
# total_tests                               -0.043955                0.031038
# total_tests_per_thousand                   0.087991                0.469052
# new_tests_per_thousand                     0.056764                0.340552
# new_tests_smoothed                        -0.072290                0.025965
# new_tests_smoothed_per_thousand            0.125680                0.359175
# positive_rate                             -0.088510               -0.050127
# tests_per_case                             0.021962                0.150055
# total_vaccinations                         0.020644                0.032154
# people_vaccinated                         -0.019480                0.037280
# people_fully_vaccinated                   -0.016312                0.027006
# new_vaccinations                           0.048071                0.007916
# new_vaccinations_smoothed                  0.040263                0.033340
# total_vaccinations_per_hundred             0.003742                0.399177
# people_vaccinated_per_hundred             -0.013497                0.391699
# people_fully_vaccinated_per_hundred       -0.011638                0.403969
# new_vaccinations_smoothed_per_million      0.067908                0.213012
# stringency_index                           0.085310                0.385800
# population                                 0.017573                0.035770
# population_density                         0.000930                0.090290
# median_age                                 0.190036                0.780057
# aged_65_older                              0.097892                0.627842
# aged_70_older                              0.097224                0.623453
# gdp_per_capita                            -0.093540                0.653821
# extreme_poverty                           -0.192317               -0.751926
# cardiovasc_death_rate                      0.414670               -0.005299
# diabetes_prevalence                        0.177364                0.467357
# female_smokers                             0.201066                0.297126
# male_smokers                               1.000000                0.327064
# handwashing_facilities                     0.327064                1.000000
# hospital_beds_per_thousand                 0.365901                0.473899
# life_expectancy                            0.062369                0.805809
# human_development_index                    0.104446                0.834572
#
#                                        hospital_beds_per_thousand  \
# total_cases                                             -0.008955
# new_cases                                               -0.009405
# new_cases_smoothed                                      -0.020080
# total_deaths                                            -0.006650
# new_deaths                                              -0.014565
# new_deaths_smoothed                                     -0.010148
# total_cases_per_million                                  0.337135
# new_cases_per_million                                    0.130420
# new_cases_smoothed_per_million                           0.264700
# total_deaths_per_million                                 0.335899
# new_deaths_per_million                                   0.124969
# new_deaths_smoothed_per_million                          0.300280
# reproduction_rate                                        0.264328
# icu_patients                                            -0.094643
# icu_patients_per_million                                 0.536136
# hosp_patients                                           -0.139882
# hosp_patients_per_million                                0.728458
# weekly_icu_admissions                                    0.319569
# weekly_icu_admissions_per_million                        0.471431
# weekly_hosp_admissions                                  -0.091518
# weekly_hosp_admissions_per_million                       0.436310
# new_tests                                                0.113310
# total_tests                                              0.013027
# total_tests_per_thousand                                 0.153828
# new_tests_per_thousand                                   0.205821
# new_tests_smoothed                                       0.020024
# new_tests_smoothed_per_thousand                          0.164780
# positive_rate                                           -0.176895
# tests_per_case                                          -0.010519
# total_vaccinations                                      -0.002788
# people_vaccinated                                       -0.017410
# people_fully_vaccinated                                 -0.025808
# new_vaccinations                                         0.001302
# new_vaccinations_smoothed                                0.006703
# total_vaccinations_per_hundred                           0.252396
# people_vaccinated_per_hundred                            0.270802
# people_fully_vaccinated_per_hundred                      0.189114
# new_vaccinations_smoothed_per_million                    0.109107
# stringency_index                                        -0.065753
# population                                              -0.020229
# population_density                                       0.310799
# median_age                                               0.648533
# aged_65_older                                            0.634582
# aged_70_older                                            0.635434
# gdp_per_capita                                           0.291599
# extreme_poverty                                         -0.443507
# cardiovasc_death_rate                                    0.041359
# diabetes_prevalence                                     -0.056418
# female_smokers                                           0.495414
# male_smokers                                             0.365901
# handwashing_facilities                                   0.473899
# hospital_beds_per_thousand                               1.000000
# life_expectancy                                          0.441971
# human_development_index                                  0.555093
#
#                                        life_expectancy  \
# total_cases                                   0.029689
# new_cases                                     0.063757
# new_cases_smoothed                            0.043178
# total_deaths                                  0.032830
# new_deaths                                    0.085535
# new_deaths_smoothed                           0.057209
# total_cases_per_million                       0.582255
# new_cases_per_million                         0.238990
# new_cases_smoothed_per_million                0.433121
# total_deaths_per_million                      0.504459
# new_deaths_per_million                        0.318153
# new_deaths_smoothed_per_million               0.468754
# reproduction_rate                             0.442701
# icu_patients                                 -0.138354
# icu_patients_per_million                     -0.278849
# hosp_patients                                -0.044875
# hosp_patients_per_million                    -0.687751
# weekly_icu_admissions                         0.286491
# weekly_icu_admissions_per_million            -0.194877
# weekly_hosp_admissions                       -0.209689
# weekly_hosp_admissions_per_million           -0.506858
# new_tests                                     0.163750
# total_tests                                   0.102685
# total_tests_per_thousand                      0.401845
# new_tests_per_thousand                        0.205062
# new_tests_smoothed                            0.124706
# new_tests_smoothed_per_thousand               0.304645
# positive_rate                                -0.192843
# tests_per_case                                0.154908
# total_vaccinations                            0.018422
# people_vaccinated                             0.017314
# people_fully_vaccinated                       0.003959
# new_vaccinations                             -0.010018
# new_vaccinations_smoothed                     0.015774
# total_vaccinations_per_hundred                0.566653
# people_vaccinated_per_hundred                 0.585752
# people_fully_vaccinated_per_hundred           0.491423
# new_vaccinations_smoothed_per_million         0.296437
# stringency_index                              0.022025
# population                                   -0.012600
# population_density                            0.230988
# median_age                                    0.845247
# aged_65_older                                 0.729375
# aged_70_older                                 0.715510
# gdp_per_capita                                0.680478
# extreme_poverty                              -0.747518
# cardiovasc_death_rate                        -0.466364
# diabetes_prevalence                           0.203408
# female_smokers                                0.459004
# male_smokers                                  0.062369
# handwashing_facilities                        0.805809
# hospital_beds_per_thousand                    0.441971
# life_expectancy                               1.000000
# human_development_index                       0.911924
#
#                                        human_development_index
# total_cases                                           0.049512
# new_cases                                             0.088289
# new_cases_smoothed                                    0.066038
# total_deaths                                          0.051179
# new_deaths                                            0.103738
# new_deaths_smoothed                                   0.080038
# total_cases_per_million                               0.622484
# new_cases_per_million                                 0.275690
# new_cases_smoothed_per_million                        0.480186
# total_deaths_per_million                              0.540299
# new_deaths_per_million                                0.284762
# new_deaths_smoothed_per_million                       0.500690
# reproduction_rate                                     0.461061
# icu_patients                                          0.093866
# icu_patients_per_million                             -0.343176
# hosp_patients                                         0.017704
# hosp_patients_per_million                            -0.813874
# weekly_icu_admissions                                -0.125731
# weekly_icu_admissions_per_million                    -0.240304
# weekly_hosp_admissions                               -0.065289
# weekly_hosp_admissions_per_million                   -0.570835
# new_tests                                             0.215710
# total_tests                                           0.156095
# total_tests_per_thousand                              0.462136
# new_tests_per_thousand                                0.240561
# new_tests_smoothed                                    0.177599
# new_tests_smoothed_per_thousand                       0.350242
# positive_rate                                        -0.216130
# tests_per_case                                        0.121170
# total_vaccinations                                    0.038434
# people_vaccinated                                     0.046385
# people_fully_vaccinated                               0.042135
# new_vaccinations                                     -0.008512
# new_vaccinations_smoothed                             0.027666
# total_vaccinations_per_hundred                        0.635171
# people_vaccinated_per_hundred                         0.665125
# people_fully_vaccinated_per_hundred                   0.530586
# new_vaccinations_smoothed_per_million                 0.261820
# stringency_index                                      0.075579
# population                                            0.002961
# population_density                                    0.180482
# median_age                                            0.897410
# aged_65_older                                         0.779996
# aged_70_older                                         0.768209
# gdp_per_capita                                        0.754559
# extreme_poverty                                      -0.777328
# cardiovasc_death_rate                                -0.420290
# diabetes_prevalence                                   0.212740
# female_smokers                                        0.582359
# male_smokers                                          0.104446
# handwashing_facilities                                0.834572
# hospital_beds_per_thousand                            0.555093
# life_expectancy                                       0.911924
# human_development_index                               1.000000
#
# [54 rows x 54 columns]

# %% [markdown]
# ### Create a correlation heatmap
#
# <font color=green>Reference</font> https://seaborn.pydata.org/examples/many_pairwise_correlations.html

# %%
# Import seaborn
import seaborn as sns

# Apply the 'white' theme
sns.set(style="white")

# Compute the correlation matrix
corr = df_covid19.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(230, 20, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0, square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Grouping data...
#
# ### Load greenhouse gas data from CSV file

# %%
body_ghg="../data/Greenhouse Gas Emissions worldwide.csv"

# %%
df_greenhouse_ = pd.read_csv(body_ghg)

# %%
df_greenhouse_
# Out:
#               Country or Area  Year  co2_gigagrams  hfc_gigagrams  \
# 0                   Australia  2012   3.978306e+05    7945.106379
# 1                   Australia  2011   3.981614e+05    7512.150105
# 2                   Australia  2010   3.993648e+05    6942.606891
# 3                   Australia  2009   3.986688e+05    6353.309697
# 4                   Australia  2008   3.990842e+05    5810.538264
# ..                        ...   ...            ...            ...
# 984  United States of America  1994   5.354404e+06            NaN
# 985  United States of America  1993   5.267711e+06            NaN
# 986  United States of America  1992   5.156781e+06            NaN
# 987  United States of America  1991   5.050478e+06            NaN
# 988  United States of America  1990   5.100606e+06            NaN
#
#      methane_gigagrams  pfc_gigagrams  sf6_gigagrams  n2o_gigagrams
# 0          111709.4988     253.697462     134.111252    25775.42951
# 1          110274.7423     259.250564     134.136620    25201.09362
# 2          109062.6389     243.764011     145.185945    24451.85748
# 3          110806.5324     307.886656     143.230925    24897.90320
# 4          113592.7600     381.135610     158.400094    25546.77744
# ..                 ...            ...            ...            ...
# 984        637199.5526            NaN            NaN            NaN
# 985        629469.5802            NaN            NaN            NaN
# 986        637785.8627            NaN            NaN            NaN
# 987        635457.4711            NaN            NaN            NaN
# 988        633201.8015            NaN            NaN            NaN
#
# [989 rows x 8 columns]

# %% [markdown]
# ### Group data by country and select the max value in each group
#
# <font color=green>Reference:</font> https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html

# %%
df_greenhouse=df_greenhouse_.groupby(['Country or Area']).max()

# %%
df_greenhouse
# Out:
#                           Year  co2_gigagrams  hfc_gigagrams  \
# Country or Area
# Australia                 2012   3.993648e+05    7945.106379
# Austria                   2012   7.939294e+04    1431.451585
# Belarus                   2012   1.038068e+05      35.798720
# Belgium                   2012   1.289664e+05    2140.194020
# Bulgaria                  2012   8.023165e+04     456.407745
# Canada                    2012   5.946590e+05    7782.902339
# Croatia                   2012   2.501834e+04     485.619120
# Cyprus                    2012   8.474103e+03     260.439180
# Czech Republic            2012   1.646942e+05    2082.748727
# Denmark                   2012   7.547074e+04     871.635964
# Estonia                   2012   3.670083e+04     167.359645
# European Union            2012   4.437028e+06   85898.389850
# Finland                   2012   7.236565e+04    1169.573600
# France                    2012   4.265645e+05   16967.744550
# Germany                   2012   1.042066e+06    9345.589459
# Greece                    2012   1.138486e+05    5365.791283
# Hungary                   2012   7.247521e+04    1144.831142
# Iceland                   2012   3.605128e+03     144.116298
# Ireland                   2012   4.762685e+04     992.276693
# Italy                     2012   4.893670e+05    9246.260023
# Japan                     2012   1.296155e+06   22925.684680
# Latvia                    2012   1.905231e+04      98.557568
# Liechtenstein             2012   2.349809e+02       8.328212
# Lithuania                 2012   3.789056e+04     240.662698
# Luxembourg                2012   1.247196e+04      67.262222
# Malta                     2012   2.806662e+03     171.109063
# Monaco                    2012   1.162889e+02       6.987987
# Netherlands               2012   1.813508e+05    9331.485100
# New Zealand               2012   3.647335e+04    1817.357764
# Norway                    2012   4.553727e+04     972.335875
# Poland                    2012   3.748120e+05    7700.220238
# Portugal                  2012   6.923649e+04    1667.323895
# Romania                   2012   1.781344e+05    1033.333671
# Russian Federation        2012   2.505380e+06   28409.780950
# Slovakia                  2012   6.180549e+04     452.031940
# Slovenia                  2012   1.800301e+04     218.634236
# Spain                     2012   3.654784e+05    8448.151668
# Sweden                    2012   6.273034e+04     869.912453
# Switzerland               2012   4.636858e+04    1245.040428
# Turkey                    2012   3.574982e+05    5308.290000
# Ukraine                   2012   7.188943e+05     726.202165
# United Kingdom            2012   5.983233e+05   18958.314860
# United States of America  2012   6.116441e+06            NaN
#
#                           methane_gigagrams  pfc_gigagrams  sf6_gigagrams  \
# Country or Area
# Australia                     117417.037200    3953.323881     316.893017
# Austria                         8332.119843    1030.484331    1233.686363
# Belarus                        15476.302800            NaN       2.419971
# Belgium                         9659.084875    2335.237300    2242.589768
# Bulgaria                       16554.783250       0.050532      14.873311
# Canada                         98609.314820    6949.976395    3873.672363
# Croatia                         3715.345018     936.564272      13.678842
# Cyprus                          1303.681967            NaN       0.087392
# Czech Republic                 17888.887000      36.658430     150.905748
# Denmark                         6154.907189      22.167718     122.202248
# Estonia                         1680.978902       0.074893       3.493939
# European Union                601172.634500   21249.989990   15813.544920
# Finland                         6169.662934      27.969400     114.935100
# France                         60972.094270    4293.450858    2899.212424
# Germany                       108798.072700    2629.685000    6779.161124
# Greece                         11212.728640     164.171045       9.918500
# Hungary                        11875.560730     270.830000     329.624020
# Iceland                          493.903842     419.631270       5.566310
# Ireland                        14417.345470     305.405900     132.202031
# Italy                          45850.093960    2486.740410     795.338163
# Japan                          32414.873250   16187.608650   17535.349590
# Latvia                          3344.394715            NaN      13.687965
# Liechtenstein                     15.754368       0.065804       0.363280
# Lithuania                       5749.548622            NaN       8.117324
# Luxembourg                       475.176140       0.242315       8.142752
# Malta                            173.993741       0.000040       4.806364
# Monaco                             1.842540       0.071358       0.200521
# Netherlands                    26053.265030    2343.913850     324.657600
# New Zealand                    30137.243630     629.870000      22.311177
# Norway                          5174.314834    3370.400605    2199.782030
# Poland                         49651.043450     177.614375      42.061097
# Portugal                       12530.088630       0.206262      45.231642
# Romania                        42945.271540    2115.834518      47.525922
# Russian Federation            593398.246300   12421.077280    5968.813695
# Slovakia                        4919.055884     271.372620      21.402629
# Slovenia                        2217.014948     302.580180      18.864670
# Spain                          33284.398730     882.916552     264.251428
# Sweden                          7060.319003     380.245706     153.098057
# Switzerland                     4652.018915     100.213415     244.716535
# Turkey                         61623.230220     744.347566     971.130304
# Ukraine                       162351.666900     203.226667      11.519800
# United Kingdom                109691.893100    1401.596677    1787.151242
# United States of America      637785.862700            NaN            NaN
#
#                           n2o_gigagrams
# Country or Area
# Australia                  26950.012510
# Austria                     6606.365153
# Belarus                    20127.224630
# Belgium                    12035.844400
# Bulgaria                   12348.286900
# Canada                     56406.648490
# Croatia                     3954.370431
# Cyprus                       746.657493
# Czech Republic             13483.487720
# Denmark                     9821.254436
# Estonia                     2244.101569
# European Union            527804.271100
# Finland                     7400.098743
# France                     93196.896320
# Germany                    85321.382860
# Greece                     10225.226680
# Hungary                    12893.371970
# Iceland                      520.586573
# Ireland                    10267.449810
# Italy                      40575.554520
# Japan                      32765.362810
# Latvia                      3816.203518
# Liechtenstein                 13.361655
# Lithuania                   7186.231290
# Luxembourg                   503.354706
# Malta                         89.424873
# Monaco                         3.533326
# Netherlands                20719.136830
# New Zealand                11052.712600
# Norway                      5043.395652
# Poland                     41785.996670
# Portugal                    6032.938791
# Romania                    24467.467380
# Russian Federation        223271.616800
# Slovakia                    6338.779108
# Slovenia                    1426.010644
# Spain                      31118.945780
# Sweden                      8114.072349
# Switzerland                 3478.256666
# Turkey                     17474.618940
# Ukraine                    58725.691200
# United Kingdom             69320.436550
# United States of America            NaN

# %% [markdown]
# ## Explore Some Data Sources:

# %% [markdown]
# ## Our World in Data
#
# https://ourworldindata.org/
#
# Source of the greenhouse gas emissions data use above:
#
# https://ourworldindata.org/co2-and-other-greenhouse-gas-emissions

# %% [markdown]
# ## US Census Data
#
# https://www2.census.gov/

# %% [markdown]
# ## Propublic Data
#
# https://www.propublica.org/datastore/
